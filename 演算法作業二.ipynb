# %%
import time
import matplotlib.pyplot as plt

def fibonacci_recursive(n):
    if n <= 1:
        return n
    else:
        return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)

def fibonacci_dynamic(n):
    fib = [0] * (n+1)
    fib[1] = 1
    for i in range(2, n+1):
        fib[i] = fib[i-1] + fib[i-2]
    return fib[n]

n_values = list(range(1, 101))
execution_times_recursive = []
execution_times_dynamic = []
plot_needed = True

for n in n_values:
    start_time = time.time()
    result = fibonacci_recursive(n)
    execution_time = time.time() - start_time
    print(f"F({n}) is {result}, calculated in {execution_time:.6f} seconds using top-down (recursive) approach.")
    execution_times_recursive.append(execution_time)

    start_time = time.time()
    result = fibonacci_dynamic(n)
    execution_time = time.time() - start_time
    print(f"F({n}) is {result}, calculated in {execution_time:.6f} seconds using bottom-up (dynamic programming) approach.")
    execution_times_dynamic.append(execution_time)

    if max(execution_times_recursive[-1], execution_times_dynamic[-1]) > 10 and plot_needed:
        plt.plot(n_values[:n], execution_times_recursive, label='Top-down (Recursive)')
        plt.plot(n_values[:n], execution_times_dynamic, label='Bottom-up (Dynamic Programming)')
        plt.xlabel('n')
        plt.ylabel('Execution Time (seconds)')
        plt.title('Execution Time of Fibonacci Calculation')
        plt.legend()
        plt.show()
        plot_needed = False
# Out:
# F(1) is 1, calculated in 0.000002 seconds using top-down (recursive) approach.
# F(1) is 1, calculated in 0.000006 seconds using bottom-up (dynamic programming) approach.
# F(2) is 1, calculated in 0.000005 seconds using top-down (recursive) approach.
# F(2) is 1, calculated in 0.000007 seconds using bottom-up (dynamic programming) approach.
# F(3) is 2, calculated in 0.000004 seconds using top-down (recursive) approach.
# F(3) is 2, calculated in 0.000006 seconds using bottom-up (dynamic programming) approach.
# F(4) is 3, calculated in 0.000006 seconds using top-down (recursive) approach.
# F(4) is 3, calculated in 0.000012 seconds using bottom-up (dynamic programming) approach.
# F(5) is 5, calculated in 0.000007 seconds using top-down (recursive) approach.
# F(5) is 5, calculated in 0.000005 seconds using bottom-up (dynamic programming) approach.
# F(6) is 8, calculated in 0.000006 seconds using top-down (recursive) approach.
# F(6) is 8, calculated in 0.000004 seconds using bottom-up (dynamic programming) approach.
# F(7) is 13, calculated in 0.000009 seconds using top-down (recursive) approach.
# F(7) is 13, calculated in 0.000004 seconds using bottom-up (dynamic programming) approach.
# F(8) is 21, calculated in 0.000017 seconds using top-down (recursive) approach.
# F(8) is 21, calculated in 0.000004 seconds using bottom-up (dynamic programming) approach.
# F(9) is 34, calculated in 0.000029 seconds using top-down (recursive) approach.
# F(9) is 34, calculated in 0.000004 seconds using bottom-up (dynamic programming) approach.
# F(10) is 55, calculated in 0.000041 seconds using top-down (recursive) approach.
# F(10) is 55, calculated in 0.000005 seconds using bottom-up (dynamic programming) approach.
# F(11) is 89, calculated in 0.000067 seconds using top-down (recursive) approach.
# F(11) is 89, calculated in 0.000014 seconds using bottom-up (dynamic programming) approach.
# F(12) is 144, calculated in 0.000126 seconds using top-down (recursive) approach.
# F(12) is 144, calculated in 0.000007 seconds using bottom-up (dynamic programming) approach.
# F(13) is 233, calculated in 0.000174 seconds using top-down (recursive) approach.
# F(13) is 233, calculated in 0.000009 seconds using bottom-up (dynamic programming) approach.
# F(14) is 377, calculated in 0.000270 seconds using top-down (recursive) approach.
# F(14) is 377, calculated in 0.000008 seconds using bottom-up (dynamic programming) approach.
# F(15) is 610, calculated in 0.000479 seconds using top-down (recursive) approach.
# F(15) is 610, calculated in 0.000007 seconds using bottom-up (dynamic programming) approach.
# F(16) is 987, calculated in 0.000729 seconds using top-down (recursive) approach.
# F(16) is 987, calculated in 0.000010 seconds using bottom-up (dynamic programming) approach.
# F(17) is 1597, calculated in 0.001275 seconds using top-down (recursive) approach.
# F(17) is 1597, calculated in 0.000011 seconds using bottom-up (dynamic programming) approach.
# F(18) is 2584, calculated in 0.001839 seconds using top-down (recursive) approach.
# F(18) is 2584, calculated in 0.000021 seconds using bottom-up (dynamic programming) approach.
# F(19) is 4181, calculated in 0.003109 seconds using top-down (recursive) approach.
# F(19) is 4181, calculated in 0.000015 seconds using bottom-up (dynamic programming) approach.
# F(20) is 6765, calculated in 0.004752 seconds using top-down (recursive) approach.
# F(20) is 6765, calculated in 0.000015 seconds using bottom-up (dynamic programming) approach.
# F(21) is 10946, calculated in 0.014570 seconds using top-down (recursive) approach.
# F(21) is 10946, calculated in 0.000016 seconds using bottom-up (dynamic programming) approach.
# F(22) is 17711, calculated in 0.020468 seconds using top-down (recursive) approach.
# F(22) is 17711, calculated in 0.000014 seconds using bottom-up (dynamic programming) approach.
# F(23) is 28657, calculated in 0.033272 seconds using top-down (recursive) approach.
# F(23) is 28657, calculated in 0.000016 seconds using bottom-up (dynamic programming) approach.
# F(24) is 46368, calculated in 0.073860 seconds using top-down (recursive) approach.
# F(24) is 46368, calculated in 0.000014 seconds using bottom-up (dynamic programming) approach.
# F(25) is 75025, calculated in 0.093293 seconds using top-down (recursive) approach.
# F(25) is 75025, calculated in 0.000016 seconds using bottom-up (dynamic programming) approach.
# F(26) is 121393, calculated in 0.214882 seconds using top-down (recursive) approach.
# F(26) is 121393, calculated in 0.000020 seconds using bottom-up (dynamic programming) approach.
# F(27) is 196418, calculated in 0.229845 seconds using top-down (recursive) approach.
# F(27) is 196418, calculated in 0.000017 seconds using bottom-up (dynamic programming) approach.
# F(28) is 317811, calculated in 0.293525 seconds using top-down (recursive) approach.
# F(28) is 317811, calculated in 0.000020 seconds using bottom-up (dynamic programming) approach.
# F(29) is 514229, calculated in 0.209584 seconds using top-down (recursive) approach.
# F(29) is 514229, calculated in 0.000020 seconds using bottom-up (dynamic programming) approach.
# F(30) is 832040, calculated in 0.340779 seconds using top-down (recursive) approach.
# F(30) is 832040, calculated in 0.000019 seconds using bottom-up (dynamic programming) approach.
# F(31) is 1346269, calculated in 0.862632 seconds using top-down (recursive) approach.
# F(31) is 1346269, calculated in 0.000021 seconds using bottom-up (dynamic programming) approach.
# F(32) is 2178309, calculated in 1.686690 seconds using top-down (recursive) approach.
# F(32) is 2178309, calculated in 0.000020 seconds using bottom-up (dynamic programming) approach.
# F(33) is 3524578, calculated in 1.456076 seconds using top-down (recursive) approach.
# F(33) is 3524578, calculated in 0.000023 seconds using bottom-up (dynamic programming) approach.
# F(34) is 5702887, calculated in 3.592389 seconds using top-down (recursive) approach.
# F(34) is 5702887, calculated in 0.000019 seconds using bottom-up (dynamic programming) approach.
# F(35) is 9227465, calculated in 3.784277 seconds using top-down (recursive) approach.
# F(35) is 9227465, calculated in 0.000021 seconds using bottom-up (dynamic programming) approach.
# F(36) is 14930352, calculated in 6.967635 seconds using top-down (recursive) approach.
# F(36) is 14930352, calculated in 0.000018 seconds using bottom-up (dynamic programming) approach.
# F(37) is 24157817, calculated in 10.334859 seconds using top-down (recursive) approach.
# F(37) is 24157817, calculated in 0.000021 seconds using bottom-up (dynamic programming) approach.
# F(38) is 39088169, calculated in 19.401821 seconds using top-down (recursive) approach.
# F(38) is 39088169, calculated in 0.000022 seconds using bottom-up (dynamic programming) approach.
# F(39) is 63245986, calculated in 33.726527 seconds using top-down (recursive) approach.
# F(39) is 63245986, calculated in 0.000023 seconds using bottom-up (dynamic programming) approach.
# F(40) is 102334155, calculated in 53.124189 seconds using top-down (recursive) approach.
# F(40) is 102334155, calculated in 0.000025 seconds using bottom-up (dynamic programming) approach.
# F(41) is 165580141, calculated in 77.062577 seconds using top-down (recursive) approach.
# F(41) is 165580141, calculated in 0.000024 seconds using bottom-up (dynamic programming) approach.
# F(42) is 267914296, calculated in 126.810708 seconds using top-down (recursive) approach.
# F(42) is 267914296, calculated in 0.000019 seconds using bottom-up (dynamic programming) approach.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-e55357ab5ed6> in <cell line: 22>()
#      22 for n in n_values:
#      23     start_time = time.time()
# ---> 24     result = fibonacci_recursive(n)
#      25     execution_time = time.time() - start_time
#      26     print(f"F({n}) is {result}, calculated in {execution_time:.6f} seconds using top-down (recursive) approach.")
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       6         return n
#       7     else:
# ----> 8         return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
#       9
#      10 def fibonacci_dynamic(n):
#
# <ipython-input-2-e55357ab5ed6> in fibonacci_recursive(n)
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 def fibonacci_recursive(n):
#       5     if n <= 1:
#       6         return n
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

def fibonacci_recursive_count(n, count):
    if n == 4:
        count[0] += 1
    if n <= 1:
        return n
    else:
        return fibonacci_recursive_count(n-1, count) + fibonacci_recursive_count(n-2, count)

count_f4 = []

for i in range(5, 51):
    count = [0]
    fibonacci_recursive_count(i, count)
    count_f4.append(count[0])
    print(f"For n = {i}, the count of F(4) computations is {count[0]}")
    if i == 40 or i == 45 or i == 50:
        plt.figure(figsize=(12, 6))
        plt.plot(list(range(5, i+1)), count_f4, label='Count of F(4) Computations', color='blue')
        plt.xlabel('n')
        plt.ylabel('Count of F(4) Computations')
        plt.title('Number of Times F(4) is Computed for F(n) (n=5 to 40)')
        plt.legend()
        plt.grid(True)
        plt.show()

n_value = list(range(5, 51))

# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(n_value, count_f4, label='Count of F(4) Computations', color='blue')
plt.xlabel('n')
plt.ylabel('Count of F(4) Computations')
plt.title('Number of Times F(4) is Computed for F(n) (n=5 to 50)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For n = 5, the count of F(4) computations is 1
# For n = 6, the count of F(4) computations is 2
# For n = 7, the count of F(4) computations is 3
# For n = 8, the count of F(4) computations is 5
# For n = 9, the count of F(4) computations is 8
# For n = 10, the count of F(4) computations is 13
# For n = 11, the count of F(4) computations is 21
# For n = 12, the count of F(4) computations is 34
# For n = 13, the count of F(4) computations is 55
# For n = 14, the count of F(4) computations is 89
# For n = 15, the count of F(4) computations is 144
# For n = 16, the count of F(4) computations is 233
# For n = 17, the count of F(4) computations is 377
# For n = 18, the count of F(4) computations is 610
# For n = 19, the count of F(4) computations is 987
# For n = 20, the count of F(4) computations is 1597
# For n = 21, the count of F(4) computations is 2584
# For n = 22, the count of F(4) computations is 4181
# For n = 23, the count of F(4) computations is 6765
# For n = 24, the count of F(4) computations is 10946
# For n = 25, the count of F(4) computations is 17711
# For n = 26, the count of F(4) computations is 28657
# For n = 27, the count of F(4) computations is 46368
# For n = 28, the count of F(4) computations is 75025
# For n = 29, the count of F(4) computations is 121393
# For n = 30, the count of F(4) computations is 196418
# For n = 31, the count of F(4) computations is 317811
# For n = 32, the count of F(4) computations is 514229
# For n = 33, the count of F(4) computations is 832040
# For n = 34, the count of F(4) computations is 1346269
# For n = 35, the count of F(4) computations is 2178309
# For n = 36, the count of F(4) computations is 3524578
# For n = 37, the count of F(4) computations is 5702887
# For n = 38, the count of F(4) computations is 9227465
# For n = 39, the count of F(4) computations is 14930352
# For n = 40, the count of F(4) computations is 24157817
# For n = 41, the count of F(4) computations is 39088169
# For n = 42, the count of F(4) computations is 63245986
